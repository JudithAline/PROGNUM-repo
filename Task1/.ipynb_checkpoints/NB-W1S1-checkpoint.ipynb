# %% [markdown]
# Ansers for week 1
# name: Judith van den Berg
# username: jaberg
# s-number: s5192773
# group: AS1

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi=22/7

# %% [markdown]
# ![poodle.jpg](attachment:poodle.jpg)

# %%
a = 6
a *= 5
a *= 4
a *= 3
a *= 2
a *= 1
a
# Out:
# 720

# %%
h = 6.626*10e-34
f = 2.42*10e28
E = (h*f)
E
# Out:
# 0.001603492

# %%
G = 6.674*10e-11
m1 = 7.342*10e22
m2 = 5.9722*10e24
r = 385000600
F = (G*m1*m2)/(r*r)
F
# Out:
# 1.974295306139031e+23

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %%
# Sirius data
m = float(input("apparentMagnitude:"))
M = float(input("absoluteMagnitude:"))

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

apparentMagnitude = m
absoluteMagnitude = M

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164

x = f"The distance to Sirius is: {d}"
print(x)
# Out:
# apparentMagnitude:-1.46
# absoluteMagnitude:1.45
# The distance to Sirius is: 8.53957042692737

# %% [markdown]
# ![screenshot%201.10.png](attachment:screenshot%201.10.png)

# %% [markdown]
# ![Screenshot%20from%202026-02-11%2017-44-15.png](attachment:Screenshot%20from%202026-02-11%2017-44-15.png)

# %% [markdown]
# ![Screenshot%20from%202026-02-11%2017-55-59.png](attachment:Screenshot%20from%202026-02-11%2017-55-59.png)
